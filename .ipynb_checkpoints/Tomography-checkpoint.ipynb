# %%
from qiskit import *
from qiskit.visualization import *
import numpy as np
from qiskit.tools.monitor import *
from qiskit.quantum_info import *
from qiskit.extensions import *
from qiskit_experiments.framework import *
from qiskit_experiments.library import *
from qiskit.test.mock import *
from qiskit.providers.aer import *

# %%
def create_circuit(qc, sent, measure = True):
    qc.append(sent, [0])
    if measure:
        qc.measure(0, 0)
    qc.barrier()
    qc.h(1)
    qc.cx(1, 2)
    qc.barrier()
    qc.cx(0, 1)
    qc.h(0)
    qc.barrier()
    qc.cx(1, 2)
    qc.cz(0, 2)
    if measure:
        qc.measure(2, 1)

# %%
 sent = Initialize(random_statevector(2))

# %%
#blochsphere circuit
qc_1 = QuantumCircuit(QuantumRegister(3), ClassicalRegister(2))
create_circuit(qc_1, sent, False)
qc_1.draw()

# %%
#histogram circuit
qc_2 = QuantumCircuit(QuantumRegister(3), ClassicalRegister(2))
create_circuit(qc_2, sent, True)
qc_2.draw()

# %%
#initializing providers
provider = IBMQ.load_account()
backend = provider.get_backend('ibmq_quito')
simulator = Aer.get_backend('qasm_simulator')
# Out:
# ibmqfactory.load_account:WARNING:2022-08-09 17:19:14,250: Credentials are already in use. The existing account in the session will be replaced.

# %%
#getting the blochsphere model for the noiseless
qc_1.save_statevector()
results_1 = execute(qc_1, backend=simulator, shots=1024).result()
received_1 = results_1.get_statevector()
plot_bloch_multivector(received_1)

# %%
quito_sim = AerSimulator.from_backend(FakeQuito())
results_2 = execute(qc_1, backend = quito_sim, shots = 1024).result()
received_2 = results_2.get_statevector()
plot_bloch_multivector(received_2)

# %%
plot_bloch_multivector(sent)

# %%
plot_state_city(results.get_statevector(qc_1), figsize = [20, 20], color = ['skyblue', 'skyblue'])

# %%
#real hardware
#job = execute(qc_2, backend = backend, shots = 1024)
#counts = job.result().get_counts()

# %%
#simulation
simjob = execute(qc_2, backend = simulator, shots = 1024)
simres = simjob.result()

# %%
#print(counts)
#print(simcounts)
#plot_histogram([counts, simcounts], legend = ['real', 'simulated'])

# %%
exp = StateTomography(qc_1)
data = exp.run(simulator, seed_simulation=1024).block_for_results()
state_analysis = data.analysis_results("state").value

# %%
exp.analysis.set_options(fitter='cvxpy_gaussian_lstsq')
data2 = exp.run(simulator, seed_simulation=1024).block_for_results()
state_analysis2 = data2.analysis_results("state")
print(state_analysis2)
print("\n")
for key, val in state_analysis2.extra.items():
    print(f"- {key}: {val}")
# Out:
# DbAnalysisResultV1
# - name: state
# - value: DensityMatrix([[ 0.16331962+0.j        ,  0.16241805+0.00274295j,
#                  0.16157259-0.00083678j,  0.16204756+0.00034019j,
#                 -0.11844852-0.02664477j, -0.11579432-0.02530061j,
#                 -0.11563396-0.03027647j, -0.11820885-0.02832515j],
#                [ 0.16241805-0.00274295j,  0.16161719+0.j        ,
#                  0.1606948 -0.00354608j,  0.16117996-0.00238361j,
#                 -0.1182609 -0.02451245j, -0.11559726-0.0232192j ,
#                 -0.11552182-0.02817159j, -0.11804992-0.02618746j],
#                [ 0.16157259+0.00083678j,  0.1606948 +0.00354608j,
#                  0.15989761+0.j        ,  0.16033252+0.00116687j,
#                 -0.11706327-0.02697086j, -0.11444354-0.02562692j,
#                 -0.11425878-0.03054959j, -0.1168169 -0.02863223j],
#                [ 0.16204756-0.00034019j,  0.16117996+0.00238361j,
# ...
