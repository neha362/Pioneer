# %%
from qiskit import *
from qiskit.visualization import *
import numpy as np
from qiskit.tools.monitor import *
from qiskit.quantum_info import *
from qiskit.extensions import *
from qiskit_experiments.framework import *
from qiskit_experiments.library import *
from qiskit.test.mock import *
from qiskit.providers.aer import *

# %%
def create_circuit(qc, sent, measure = True):
    qc.append(sent, [0])
    if measure:
        qc.measure(0, 0)
    qc.barrier()
    qc.h(1)
    qc.cx(1, 2)
    qc.barrier()
    qc.cx(0, 1)
    qc.h(0)
    qc.barrier()
    qc.cx(1, 2)
    qc.cz(0, 2)
    if measure:
        qc.measure(2, 1)

# %%
 sent = Initialize(random_statevector(2))

# %%
#histogram circuit
qc = QuantumCircuit(QuantumRegister(3), ClassicalRegister(2))
create_circuit(qc, sent, True)
qc.draw()

# %%
#initializing backends
provider = IBMQ.load_account()
backend = provider.get_backend('ibmq_quito')
quito_sim = AerSimulator.from_backend(FakeQuito())
simulator = Aer.get_backend('qasm_simulator')

# %%
#real hardware
job = execute(qc, backend = backend, shots = 1024)
results = job.result()
counts = results.get_counts()

# %%
#noiseless simulation
simjob = execute(qc, backend = simulator, shots = 1024)
simres = simjob.result()
simcounts = simres.get_counts()

# %%
#noisy simulation
noisejob = execute(qc, backend = quito_sim, shots = 1024)
noiseres = noisejob.result()
noisecounts = noiseres.get_counts()

# %%
print(counts)
print(simcounts)
print(noisecounts)
plot_histogram([counts, simcounts, noisecounts], legend = ['real', 'noiseless simulation', 'noisy simulation'])
# Out:
# {'00': 808, '01': 47, '10': 72, '11': 97}
# {'00': 894, '11': 130}
# {'00': 785, '11': 117, '10': 80, '01': 42}

# %%
exp = StateTomography(qc)
data = exp.run(simulator, seed_simulation=1024).block_for_results()
state_analysis = data.analysis_results("state").value

# %%
'''
exp.analysis.set_options(fitter='cvxpy_gaussian_lstsq')
data2 = exp.run(simulator, seed_simulation=1024).block_for_results()
state_analysis2 = data2.analysis_results("state")
print(state_analysis2)
print("\n")
for key, val in state_analysis2.extra.items():
    print(f"- {key}: {val}")
'''
# Out:
# '\nexp.analysis.set_options(fitter=\'cvxpy_gaussian_lstsq\')\ndata2 = exp.run(simulator, seed_simulation=1024).block_for_results()\nstate_analysis2 = data2.analysis_results("state")\nprint(state_analysis2)\nprint("\n")\nfor key, val in state_analysis2.extra.items():\n    print(f"- {key}: {val}")\n'

# %%
plot_state_city(results.get_statevector(qc), figsize = [20, 10], color = ['skyblue', 'skyblue'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\qiskit\result\result.py:325, in Result.get_statevector(self, experiment, decimals)
#     323 try:
#     324     return postprocess.format_statevector(
# --> 325         self.data(experiment)["statevector"], decimals=decimals
#     326     )
#     327 except KeyError as ex:
#
# KeyError: 'statevector'
#
# The above exception was the direct cause of the following exception:
#
# QiskitError                               Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 plot_state_city(results.get_statevector(qc), figsize = [20, 10], color = ['skyblue', 'skyblue'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\qiskit\result\result.py:328, in Result.get_statevector(self, experiment, decimals)
#     324     return postprocess.format_statevector(
#     325         self.data(experiment)["statevector"], decimals=decimals
#     326     )
#     327 except KeyError as ex:
# --> 328     raise QiskitError(f'No statevector for experiment "{repr(experiment)}"') from ex
#
# QiskitError: 'No statevector for experiment "<qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x00000222939BEDC0>"'

# %%
plot_state_city(simres.get_statevector(qc), figsize = [20, 10], color = ['skyblue', 'skyblue'])

# %%
plot_state_city(noiseres.get_statevector(qc), figsize = [20, 10], color = ['skyblue', 'skyblue'])
